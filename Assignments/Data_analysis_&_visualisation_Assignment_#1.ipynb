# %% [markdown]
# # Assignment #1
#
# * **Name : Siam Hossain**
# * **Data Analysis & Visualisation**

# %%
## For creating a dataset from the informations in given csv file

import pandas as pd

df = pd.read_csv("Life_Expectancy_Data.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2864 entries, 0 to 2863
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      2864 non-null   object
#  1   Region                       2864 non-null   object
#  2   Year                         2864 non-null   int64
#  3   Infant_deaths                2864 non-null   float64
#  4   Under_five_deaths            2864 non-null   float64
#  5   Adult_mortality              2864 non-null   float64
#  6   Alcohol_consumption          2864 non-null   float64
#  7   Hepatitis_B                  2864 non-null   int64
#  8   Measles                      2864 non-null   int64
#  9   BMI                          2864 non-null   float64
#  10  Polio                        2864 non-null   int64
#  11  Diphtheria                   2864 non-null   int64
#  12  Incidents_HIV                2864 non-null   float64
# ...

# %% [markdown]
# # Function to Save Figures

# %%
# code to save the figures as high-res PNGs
import os
from pathlib import Path
from matplotlib import pyplot as plt

IMAGES_PATH = Path() / "Images/Data_Visualization"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ## Question 01.
#
# * 👨‍💻***Analyse the avg life expectancy rate in Argentina & present the countries population growth over the years.***

# %% [markdown]
# # Ans.to.the.Ques.No.01:

# %%
# filtering the informations of Argentina from the created dataset
data_argentina = df.query('Country.str.startswith("Argentina")')

data_argentina
# Out:
#         Country         Region  Year  Infant_deaths  Under_five_deaths  \
# 72    Argentina  South America  2014           10.8               12.1
# 85    Argentina  South America  2005           14.8               16.5
# 304   Argentina  South America  2002           16.4               18.3
# 441   Argentina  South America  2001           16.9               18.9
# 775   Argentina  South America  2012           11.9               13.3
# 1103  Argentina  South America  2013           11.3               12.7
# 1272  Argentina  South America  2004           15.3               17.1
# 1353  Argentina  South America  2011           12.4               13.9
# 1901  Argentina  South America  2006           14.4               16.1
# 1916  Argentina  South America  2009           13.3               14.9
# 1951  Argentina  South America  2007           14.0               15.7
# 2366  Argentina  South America  2010           12.9               14.5
# ...

# %%
# For calculating the avg life expectency in Argentina
import numpy as np
avg_arg_life = np.mean(data_argentina["Life_expectancy"])

print("Average life expectency in Argentina is: ",avg_arg_life,"years")
# Out:
# Average life expectency in Argentina is:  74.8625 years

# %%
data_argentina.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16 entries, 72 to 2845
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      16 non-null     object
#  1   Region                       16 non-null     object
#  2   Year                         16 non-null     int64
#  3   Infant_deaths                16 non-null     float64
#  4   Under_five_deaths            16 non-null     float64
#  5   Adult_mortality              16 non-null     float64
#  6   Alcohol_consumption          16 non-null     float64
#  7   Hepatitis_B                  16 non-null     int64
#  8   Measles                      16 non-null     int64
#  9   BMI                          16 non-null     float64
#  10  Polio                        16 non-null     int64
#  11  Diphtheria                   16 non-null     int64
#  12  Incidents_HIV                16 non-null     float64
# ...

# %%
# Presenting the population growth over the years in Argentina using Line plot.
import matplotlib.pyplot as pt
import seaborn as sb

# Set the size for plotting
pt.figure(figsize = (12, 8))

# Using seaborn for line plot
sb.lineplot(data = data_argentina, x = df["Year"], y = df["Population_mln"], color = "blue", n_boot = 1)

# Customizing the plot
pt.title("Argentina - Population growth over the years")
pt.xlabel("Years")
pt.ylabel("Population(mln)")
pt.grid()

# rotating the xlabel
pt.xticks(rotation = 45)

# saving the figure
save_fig("Argentina - Population growth over the years")

# showing
pt.show()

# %% [markdown]
# ## 📊Conclusion
#
# * ***So, we can state from our above analysis that; in Argentina the average life expectency rate is 74.8625 years. In addition, from our line plot we can state that over the years the population growth is increasing in Argentina. Where, the lowest number of population was in 2004 & the highest number of population was in 2012.***

# %% [markdown]
# # Question 02.
#
# * 👨‍💻***Find the number of developed countires then visualize it for analysing the difference of developement.***

# %% [markdown]
# # Ans.to.the.Ques.No.02 :

# %%
# Cleaning the data by droping the duplicates for getting the main list of countires

cleaned_country_list = df.drop_duplicates(subset = "Country", keep = "first")

# %%
cleaned_country_list.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 179 entries, 0 to 1378
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      179 non-null    object
#  1   Region                       179 non-null    object
#  2   Year                         179 non-null    int64
#  3   Infant_deaths                179 non-null    float64
#  4   Under_five_deaths            179 non-null    float64
#  5   Adult_mortality              179 non-null    float64
#  6   Alcohol_consumption          179 non-null    float64
#  7   Hepatitis_B                  179 non-null    int64
#  8   Measles                      179 non-null    int64
#  9   BMI                          179 non-null    float64
#  10  Polio                        179 non-null    int64
#  11  Diphtheria                   179 non-null    int64
#  12  Incidents_HIV                179 non-null    float64
# ...

# %%
# Finding the number of developed countries [0 : Not developed; 1: Developed]
cleaned_country_list["Economy_status_Developed"].value_counts()
# Out:
# Economy_status_Developed
# 0    142
# 1     37
# Name: count, dtype: int64

# %%
# Now visualizing our result using countplot
import matplotlib.pyplot as pt
import seaborn as sb

# Set the size for plotting
pt.figure(figsize = (8, 4))

# Using seaborn for countplot
sb.countplot(data = cleaned_country_list, x = cleaned_country_list["Economy_status_Developed"], palette = "dark")

# Customizing the plot
pt.grid()
pt.xlabel("Developed Status", size = 8, fontstyle = "italic", weight = 500)
pt.ylabel("Country Count", size = 8, fontstyle = "italic", weight = 500)
pt.title("Number of Developed countries")

# saving the figure
save_fig("Number of Developed countries")

# showing
pt.show()

# %% [markdown]
# ## 📊Conclusion
#
# * ***So, we can state from our above analysis that; in our dataset there are only 37 developed countries among 179 taken countries. Also from our countplot it is clearly visible that development differences are high in our dataset.***

# %% [markdown]
# # Question 03.
# * 👨‍💻***Show the analysis of schooling frequency.***

# %% [markdown]
# # Ans.to.the.Ques.No.03 :

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2864 entries, 0 to 2863
# Data columns (total 21 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Country                      2864 non-null   object
#  1   Region                       2864 non-null   object
#  2   Year                         2864 non-null   int64
#  3   Infant_deaths                2864 non-null   float64
#  4   Under_five_deaths            2864 non-null   float64
#  5   Adult_mortality              2864 non-null   float64
#  6   Alcohol_consumption          2864 non-null   float64
#  7   Hepatitis_B                  2864 non-null   int64
#  8   Measles                      2864 non-null   int64
#  9   BMI                          2864 non-null   float64
#  10  Polio                        2864 non-null   int64
#  11  Diphtheria                   2864 non-null   int64
#  12  Incidents_HIV                2864 non-null   float64
# ...

# %%
# Will use the Histogram for showing the frequency of schooling in our dataset
import matplotlib.pyplot as pt
import seaborn as sb

# Set the size for plotting
pt.figure(figsize = (12, 8))

# Using seaborn for countplot
sb.histplot(data = df, x = df["Schooling"], kde = True)

# Customizing the plot
pt.grid()
pt.xlabel("Schooling", size = 15, fontstyle = "italic", weight = 700)
pt.ylabel("Schooling frequency", size = 15, fontstyle = "italic", weight = 700)
pt.title("Frequency of schooling in dataset")

# saving the figure
save_fig("Frequency of schooling in dataset")

# showing
pt.show()

# %% [markdown]
# ## 📊Conclusion
#
# * ***So, we can state from our above analysis that; in our dataset the higher ratio of schooling is from 8% to near 12%.***

# %% [markdown]
# # Question 04 .
# * 👨‍💻***Visualize the effect of the alcohol consumption on the adult mortality rate.***

# %% [markdown]
# # Ans.to.the.Ques.No.04 :

# %%
# Use Scatter plot for showing the relation between Alcohol consumption & Adult mortality
import matplotlib.pyplot as pt
import seaborn as sb

# Set the size
pt.figure(figsize = (12,  8))

# Scatter plot
sb.scatterplot(data = df, x = df["Alcohol_consumption"], y = df["Adult_mortality"], color = "red")

# Customizing the plot
pt.grid()
pt.title("Effect of Alcohol consumption on Adult mortality rate")
pt.xlabel("Alcohol consumptions", size = 15, fontstyle = "italic", weight = 700)
pt.ylabel("Adult mortality", size = 15, fontstyle = "italic", weight = 700)

# save the figure
save_fig("Effect of Alcohol consumption on Adult mortality rate")

# showing
pt.show()

# %% [markdown]
# ## 📊Conclusion
#
# * ***So, we can state from our above scatter plot that; the lower the alcohol consumption, the higher the adult mortality rate.***

# %% [markdown]
# # Question 05 .
# * 👨‍💻***Analyse the BMI in the dataset then analyse & visualize the BMI for the year 2015.***

# %% [markdown]
# # Ans.to.the.Ques.No.05 :

# %%
# analyzing the BMI by calculations
import numpy as np
bmi_data = df["BMI"]

mean_bmi = np.mean(bmi_data)


minimum_bmi = bmi_data.min()
maximum_bmi = bmi_data.max()

print("Average BMI: ", mean_bmi)
print("Minimum BMI: ", minimum_bmi)
print("Maximum BMI: ", maximum_bmi)
# Out:
# Average BMI:  25.032925977653633
# Minimum BMI:  19.8
# Maximum BMI:  32.1

# %%
# filtering the datas for year 2015

df_2015 = df.query('Year == 2015')

# %%
# Using Box plot to visualize the BMI for the year 2015
import matplotlib.pyplot as pt
import seaborn as sb

# Set size
pt.figure(figsize = (6, 4))

# Using Box plot
sb.boxplot(x = df_2015["BMI"])

# Customizing the plottings
pt.xlabel("BMI")
pt.title("Box Plot for BMI in 2015")
pt.grid()

# Saving the figure
save_fig("Box Plot for BMI in 2015")

# showing
plt.show()

# %%
# Analysis from Box plot

analysing_2015_bmi = df_2015["BMI"]

Q1 = analysing_2015_bmi.quantile(0.25)
Q2 = analysing_2015_bmi.median()
Q3 = analysing_2015_bmi.quantile(0.75)
IQR = Q3 - Q1

minimum = analysing_2015_bmi.min()
maximum = analysing_2015_bmi.max()

# Printing the Q1, Q2. Q3, IQR, minimum, maximum

print("Q1: ", Q1)
print("Median: ", Q2)
print("Q3: ", Q3)
print("IQR: ", IQR)
print("Minimum: ", minimum)
print("Maximum: ", maximum)

df_2015.describe()
# Out:
# Q1:  23.8
# Median:  26.2
# Q3:  27.0
# IQR:  3.1999999999999993
# Minimum:  20.5
# Maximum:  32.1
#          Year  Infant_deaths  Under_five_deaths  Adult_mortality  \
# count   179.0     179.000000         179.000000        179.00000
# mean   2015.0      23.558659          31.680447        163.66757
# std       0.0      21.487508          32.217096         89.95447
# min    2015.0       1.800000           2.300000         49.38400
# 25%    2015.0       6.650000           7.850000         90.78575
# 50%    2015.0      15.200000          17.500000        146.51950
# 75%    2015.0      36.550000          49.950000        215.64925
# max    2015.0      95.100000         140.200000        513.47550
#
#        Alcohol_consumption  Hepatitis_B     Measles         BMI      Polio  \
# count           179.000000   179.000000  179.000000  179.000000  179.00000
# mean              4.728994    87.100559   80.229050   25.596089   88.26257
# ...

# %% [markdown]
# ## 📊Conclusion
#
# * *for overall dataset---> Average BMI: 25.03, Minimum BMI: 19.8, Maximum BMI: 32.1*
#
#
# * *for the year 2015---> The value below which 25% of the data falls:  23.8, The middle value of the dataset: 26.2, The value below which 75% of the data falls: 27.0, Maximum BMI: 20.5 & Minimum BMI: 32.1 which is also visualized by our box plot*

# %% [markdown]
# # Question 06.
# * 👨‍💻***Analyse the Regional HIV cases.***

# %% [markdown]
# # Ans.to.the.Ques.No.06 :

# %%
# Using Swarm Plot for analysing the regional HIV case
import matplotlib.pyplot as pt
import seaborn as sb

# Set the size
pt.figure(figsize = (12, 8))

# Creating swarm plot
sb.swarmplot(data = df, x = df["Region"], y = df["Incidents_HIV"], color = "green", size = 3)

# Customizing
pt.title("Regional HIV Case Ratio")
pt.xlabel("Regions")
pt.ylabel("HIV %")
pt.grid()
pt.tight_layout()

pt.xticks(rotation = 45)

# save the figure
save_fig("Regional HIV Case Ratio")

# show the figure
pt.show()
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 90.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 83.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\hp\anaconda3\Lib\site-packages\seaborn\categorical.py:3544: UserWarning: 64.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %% [markdown]
# ## 📊Conclusion
#
# * ***So from this Swarm Plot we can easily represent that; in Africa region the HIV case ratio is highest among other 8 regions***
