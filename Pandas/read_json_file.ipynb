# %% [markdown]
# # Loading a JSON File

# %%
# Load the library
import pandas as pd

# Load data
df = pd.read_json("products.json")

# View 
df
# Out:
#                                     Id          Maker  \
# 0                     jenlooper-cactus     @jenlooper
# 1                      jenlooper-light      jenlooper
# 2                  jenlooper-lightshow     @jenlooper
# 3                   jenlooper-survival      jenlooper
# 4               sailorhg-bubblesortpic       sailorhg
# 5                     sailorhg-corsage       sailorhg
# 6                         sailorhg-kit       sailorhg
# 7                         sailorhg-led       sailorhg
# 8              selinazawacki-soi-shirt  selinazawacki
# 9               selinazawacki-soi-pins  selinazawacki
# 10        vogueandcode-hipster-dev-bro   vogueandcode
# 11  vogueandcode-pretty-girls-code-tee   vogueandcode
# 12             vogueandcode-ruby-sis-2   vogueandcode
# 13                  selinazawacki-moon  selinazawacki
# 14                 selinazawacki-shirt  selinazawacki
#
#                                                   img  \
# ...
