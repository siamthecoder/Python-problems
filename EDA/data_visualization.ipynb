# %% [markdown]
# # Data Visualization

# %%
# Load libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as pt
import seaborn as sb

# %%
# Load the dataset
df = pd.read_csv("diabetes_binary_5050split_health_indicators_BRFSS2015 - diabetes_binary_5050split_health_indicators_BRFSS2015.csv")

# %%
df.head()
# Out:
#    Diabetes_binary  HighBP  HighChol  CholCheck  BMI  Smoker  Stroke  \
# 0                0       1         0          1   26       0       0
# 1                0       1         1          1   26       1       1
# 2                0       0         0          1   26       0       0
# 3                0       1         1          1   28       1       0
# 4                0       0         0          1   29       1       0
#
#    HeartDiseaseorAttack  PhysActivity  Fruits  ...  AnyHealthcare  \
# 0                     0             1       0  ...              1
# 1                     0             0       1  ...              1
# 2                     0             1       1  ...              1
# 3                     0             1       1  ...              1
# 4                     0             1       1  ...              1
#
#    NoDocbcCost  GenHlth  MentHlth  PhysHlth  DiffWalk  Sex  Age  Education  \
# ...

# %%
df["Diabetes_binary"].value_counts()
# Out:
# Diabetes_binary
# 0    35346
# 1    35346
# Name: count, dtype: int64

# %%
# code to save the figures as high-res PNGs
import os
from pathlib import Path
from matplotlib import pyplot as plt

IMAGES_PATH = Path() / "Images/Data_Visualization"
IMAGES_PATH.mkdir(parents=True, exist_ok=True)

def save_fig(fig_id, tight_layout=True, fig_extension="png", resolution=300):
    path = IMAGES_PATH / f"{fig_id}.{fig_extension}"
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format=fig_extension, dpi=resolution)

# %% [markdown]
# ## Diabetes target variable count

# %%
# set the size for plotting
pt.figure(figsize = (7,5))

# creating a pie chart
pt.pie([df["Diabetes_binary"].value_counts()[0], df["Diabetes_binary"].value_counts()[1]], 
       labels = ['No Diabetes (0)', 'Diabetes (1)'], autopct = "%1.1f%%", startangle = 90)

# Customizing the plot
pt.title("Diabetes Records")

# saving the img
save_fig("Distribution of Diabetes Records")

# showing the plot
pt.show()

# %% [markdown]
# ## Diabetes Records per Gender

# %%
# 0 = no diabetes
# 1 = pre-diabetes
# 0 - female
# 1 - male

# Create a count plot
sb.countplot(data = df, x = df["Diabetes_binary"], hue = "Sex", palette = "rocket")

# Customizing
pt.xlabel("Diabetes status", size = 10, fontstyle = "oblique", weight = 650)
pt.ylabel("Count", size = 10, fontstyle = "oblique", weight = 650)
pt.grid()
pt.title("Diabetes Records - Genderwise")

# Customization for differentiate
pt.legend(title = "Gender", labels = ["Female", "Male"])
pt.xticks(ticks = [0,1], labels = ["No Diabetes", "Pre Diabetes"])

# Saving the figure
save_fig("Diabetes Records per Gender")

# Showing
pt.show()

# %% [markdown]
# # Relationship between diabetes and stroke

# %%
# 0 = no stroke
# 1 = stroke
# 0 - no diabetes
# 1 - pre diabetes

# Create a count plot
sb.countplot(data = df, x = df["Diabetes_binary"], hue = "Stroke", palette = "viridis")

# Customizing
pt.xlabel("Diabetes status", size = 10, fontstyle = "oblique", weight = 650)
pt.ylabel("Count", size = 10, fontstyle = "oblique", weight = 650)
pt.grid()
pt.title("Diabetes Records - Strokewise")

# Customization for differentiate
pt.legend(title = "Stroke status", labels = ["NO", "YES"])
pt.xticks(ticks = [0,1], labels = ["No Diabetes", "Pre Diabetes"])

# Saving the figure
save_fig("Diabetes Records per Stroke occurrence")

# Showing
pt.show()

# %% [markdown]
# ## Relationship between diabetes and Blood Pressure

# %%
# Create a count plot
sb.countplot(data = df, x = df["Diabetes_binary"], hue = "HighBP", palette = "mako")

# Customizing
pt.xlabel("Diabetes status", size = 10, fontstyle = "oblique", weight = 650)
pt.ylabel("Count", size = 10, fontstyle = "oblique", weight = 650)
pt.grid()
pt.title("Diabetes Records - BPwise")

# Customization for differentiate
pt.legend(title = "Blood Pressure Level", labels = ["Low", "High"])
pt.xticks(ticks = [0,1], labels = ["No Diabetes", "Pre Diabetes"])

# Saving the figure
save_fig("Diabetes Records per Blood pressure lavel")

# Showing
pt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70692 entries, 0 to 70691
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Diabetes_binary       70692 non-null  int64
#  1   HighBP                70692 non-null  int64
#  2   HighChol              70692 non-null  int64
#  3   CholCheck             70692 non-null  int64
#  4   BMI                   70692 non-null  int64
#  5   Smoker                70692 non-null  int64
#  6   Stroke                70692 non-null  int64
#  7   HeartDiseaseorAttack  70692 non-null  int64
#  8   PhysActivity          70692 non-null  int64
#  9   Fruits                70692 non-null  int64
#  10  Veggies               70692 non-null  int64
#  11  HvyAlcoholConsump     70692 non-null  int64
#  12  AnyHealthcare         70692 non-null  int64
#  13  NoDocbcCost           70692 non-null  int64
#  14  GenHlth               70692 non-null  int64
# ...

# %% [markdown]
# ## Relationship between diabetes and Cholestorel

# %%
# Create a count plot
sb.countplot(data = df, x = df["Diabetes_binary"], hue = "HighChol", palette = "flare")

# Customizing
pt.xlabel("Diabetes status", size = 10, fontstyle = "oblique", weight = 650)
pt.ylabel("Count", size = 10, fontstyle = "oblique", weight = 650)
pt.grid()
pt.title("Diabetes Records - Cholestorelwise")

# Customization for differentiate
pt.legend(title = "Cholestorel Level", labels = ["Low", "High"])
pt.xticks(ticks = [0,1], labels = ["No Diabetes", "Pre Diabetes"])

# Saving the figure
save_fig("Diabetes Records per Cholestorel lavel")

# Showing
pt.show()

# %% [markdown]
# ## Relationship between Diabetes & Smoking

# %%
# Create a count plot
sb.countplot(data = df, x = df["Diabetes_binary"], hue = "Smoker", palette = "cubehelix")

# Customizing
pt.xlabel("Diabetes status", size = 10, fontstyle = "oblique", weight = 650)
pt.ylabel("Count", size = 10, fontstyle = "oblique", weight = 650)
pt.grid()
pt.title("Diabetes Records - Smokingwise")

# Customization for differentiate
pt.legend(title = "Smoking status", labels = ["NO", "YES"])
pt.xticks(ticks = [0,1], labels = ["No Diabetes", "Pre Diabetes"])

# Saving the figure
save_fig("Diabetes Records per Smoking status")

# Showing
pt.show()

# %% [markdown]
# ## Histogram of BMI

# %%
# Creating a histplot
sb.histplot(data = df, bins = 20, x = df["BMI"], kde = True, color = "brown")

# Customizing
pt.xlabel("BMI")
pt.ylabel("Frequency")
pt.grid()
pt.title("Histplot of BMI")

# saving the figure
save_fig("BMI - Histogram analysis")

# showing
pt.show()
